# %% [markdown]
# # Protein Transformer: No Tokenization

# %%
# (Please, be aware that it might be necessary to import this library for the hiperparameter tuning)
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian_optimization-2.0.0-py3-none-any.whl.metadata (8.9 kB)
# Collecting colorama<0.5.0,>=0.4.6 (from bayesian-optimization)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.5.2)
# Requirement already satisfied: scipy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bayesian-optimization) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->bayesian-optimization) (3.5.0)
# Downloading bayesian_optimization-2.0.0-py3-none-any.whl (30 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama, bayesian-optimization
# Successfully installed bayesian-optimization-2.0.0 colorama-0.4.6

# %%
# Set Up & Libraries

import pandas as pd
import numpy as np
import time
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import KFold
from bayes_opt import BayesianOptimization
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, ConfusionMatrixDisplay, confusion_matrix
import os
import random
import seaborn as sns

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Device: {device}')
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
os.environ['TORCH_USE_CUDA_DSA'] = '1'

seed = 10
torch.manual_seed(seed)
np.random.seed(seed)
# Out:
# Device: cuda

# %%
# Importing Dataset
df = pd.read_csv("/content/2018-06-06-pdb-intersect-pisces.csv")
print(df.shape)
print(df.columns)
# Out:
# (9078, 11)
# Index(['pdb_id', 'chain_code', 'seq', 'sst8', 'sst3', 'len', 'has_nonstd_aa',
#        'Exptl.', 'resolution', 'R-factor', 'FreeRvalue'],
#       dtype='object')

# %%
# Test Set

test_size = int(.1 * df.shape[0]) # 10% of data for test set
test_ix = random.sample([i for i in range(df.shape[0])] , test_size)
df_test = df.iloc[test_ix]
df = df.drop(test_ix)
print(df.shape)
print(df_test.shape)
# Out:
# (8171, 11)
# (907, 11)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# (Please, be aware that this section is the same across notebooks with the same tokenization technique)

# %% [markdown]
# ## Padding & Cropping

# %%
def pad_sequence(seq_df, maxlen):
    """This function pads with dots a sequence until it has the desired length"""
    out = ['<'+i+'>'+'.'*(maxlen-len(i)) for i in seq_df]
    return out

def crop_sequence(seq_long , max_len):
    """This function breaks a sequence into subsequences of the desired length"""
    # Cracking Sequence
    out_1 = ['<'+seq_long[j][i-max_len:i]+'.' if i==0 else '.'+seq_long[j][i-max_len:i]+'.' for j in seq_long.index for i in range(max_len , len(seq_long[j]) , max_len)]
    # Extracting and padding last part of each sequence
    out_2 = [seq_long[j][max_len * (int(len(seq_long[j])/max_len)) : len(seq_long[j])] for j in seq_long.index]
    out_2 = pad_sequence(out_2 , max_len)
    # Unifying both
    out_1.extend(out_2)
    return out_1

def crop_pad_sequences(df , max_len):
  # Dividing Dataset
  df_short = df[df['seq'].str.len() < max_len] # Needs padding
  df_exact = df[df['seq'].str.len() == max_len] # Nothing
  df_long = df[df['seq'].str.len() > max_len] # Needs Cropping

  # Preparing features
  seq_short = pad_sequence(df_short['seq'], max_len)
  seq_exact = ['<'+i+'>' for i in df_exact['seq']]
  seq_long = crop_sequence(df_long['seq'], max_len)
  seq_features = [i for l in [seq_short, seq_exact, seq_long] for i in l] # Joining all three
  print(f'Number of Sequences: {len(seq_features)}')

  # Preparing q3
  q3_short = pad_sequence(df_short['sst3'], max_len)
  q3_exact = ['<'+i+'>' for i in df_exact['sst3']]
  q3_long = crop_sequence(df_long['sst3'], max_len)
  q3 = [i for l in [q3_short, q3_exact, q3_long] for i in l] # Joining all three
  print(f'Number of Sequences: {len(q3)}')

  # Preparing q8
  q8_short = pad_sequence(df_short['sst8'], max_len)
  q8_exact = ['<'+i+'>' for i in df_exact['sst8']]
  q8_long = crop_sequence(df_long['sst8'], max_len)
  q8 = [i for l in [q8_short, q8_exact, q8_long] for i in l] # Joining all three
  print(f'Number of Sequences: {len(q8)}')

  # Checking
  for i in [q8 , q3 , seq_features]:
      lens = [len(j) for j in i]
      print(f'Sequences without desired length: {[j for j in lens if j != max_len+2]}')

  return seq_features , q3 , q8

# %%
# Sequence Standarization
max_len = int(np.mean(df['len'])) #Hyperparam

seq_features , q3 , q8 = crop_pad_sequences(df , max_len)
# Out:
# Number of Sequences: 13473
# Number of Sequences: 13473
# Number of Sequences: 13473
# Sequences without desired length: []
# Sequences without desired length: []
# Sequences without desired length: []

# %% [markdown]
# ## Encoders, Decoders & Vocabs

# %%
def enc_dec_vocab(sequence):
  seq_vocab = np.unique([j for i in sequence for j in i]) # Vocab Dictionary
  seq_stoi = {str(j):i for i,j in enumerate(seq_vocab)} # String-to-Int
  seq_itos = {i:str(j) for i,j in enumerate(seq_vocab)} # Int-to-String
  seq_encoder = lambda s: [seq_stoi[c] for c in s] # encoder function
  seq_decoder = lambda s: [seq_itos[c] for c in s] # decoder function
  print(f'Sequence vocabulary: {seq_vocab} | Vocab Length: {len(seq_vocab)}\n\n')

  return seq_encoder , seq_decoder , seq_vocab, seq_stoi, seq_itos

# %%
# Features
seq_encoder , seq_decoder , seq_vocab, seq_stoi, seq_itos = enc_dec_vocab(seq_features)
# Q3
q3_encoder , q3_decoder , q3_vocab, q3_stoi, q3_itos = enc_dec_vocab(q3)
# Q8
q8_encoder , q8_decoder , q8_vocab, q8_stoi, q8_itos = enc_dec_vocab(q8)
# Out:
# Sequence vocabulary: ['*' '.' '<' '>' 'A' 'C' 'D' 'E' 'F' 'G' 'H' 'I' 'K' 'L' 'M' 'N' 'P' 'Q'
#  'R' 'S' 'T' 'V' 'W' 'Y'] | Vocab Length: 24
#
#
# Sequence vocabulary: ['.' '<' '>' 'C' 'E' 'H'] | Vocab Length: 6
#
#
# Sequence vocabulary: ['.' '<' '>' 'B' 'C' 'E' 'G' 'H' 'I' 'S' 'T'] | Vocab Length: 11

# %% [markdown]
# ## Data Exploration

# %%
# Descriptive statistics for sequence lengths
sequence_lengths = df['len']
print("\nDescriptive Statistics for Sequence Lengths:")
print(sequence_lengths.describe())

# Visualizing the distribution with descriptive statistics
plt.figure(figsize=(6, 4))
sns.histplot(sequence_lengths, bins=30, kde=True, color='green')
plt.title('Distribution of Sequence Lengths')
plt.xlabel('Sequence Length')
plt.ylabel('Frequency')
plt.axvline(sequence_lengths.mean(), color='r', linestyle='--', label=f'Mean: {sequence_lengths.mean():.2f}')
plt.axvline(sequence_lengths.median(), color='b', linestyle='--', label=f'Median: {sequence_lengths.median():.2f}')
plt.legend()
plt.show()



# Conclusion: Highly skewed distribution of lengths
# Out:
# Descriptive Statistics for Sequence Lengths:
# count    8978.000000
# mean      243.261305
# std       156.661380
# min        20.000000
# 25%       132.000000
# 50%       208.000000
# 75%       324.000000
# max      1632.000000
# Name: len, dtype: float64

# %%
# Statistics for Class Frequency in Each Data Type (Sequence, Q3 & Q8)

colors_seq = sns.color_palette("coolwarm", len(seq_vocab))
seqs = np.array([seq_encoder(i) for i in seq_features])
seqs_freqs = np.unique(seqs , return_counts  = True)
seq_freqs = {i[0]:i[1] for i in zip(seqs_freqs[0] , seqs_freqs[1])}
plt.figure(figsize=(12, 6))
plt.bar([seq_itos[i] for i in list(seq_freqs.keys())] , seq_freqs.values() , color=colors_seq, edgecolor='grey')
plt.title('Sequence Frequencies', fontsize=16, weight='bold')
plt.xlabel('Sequence', fontsize=12, labelpad=10)
plt.ylabel('Frequency', fontsize=12, labelpad=10)
plt.xticks(rotation=45 , ticks = list(seq_freqs.keys()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()


colors_q3 = sns.color_palette("coolwarm", len(q3_vocab))
q3s = np.array([q3_encoder(i) for i in q3])
q3s_freqs = np.unique(q3s , return_counts  = True)
q3s_freqs = {i[0]:i[1] for i in zip(q3s_freqs[0] , q3s_freqs[1])}
plt.figure(figsize=(12, 6))
plt.bar([q3_itos[i] for i in list(q3s_freqs.keys())] , q3s_freqs.values() , color=colors_q3, edgecolor='grey')
plt.title('Q3 Frequencies', fontsize=16, weight='bold')
plt.xlabel('Q3', fontsize=12, labelpad=10)
plt.ylabel('Frequency', fontsize=12, labelpad=10)
plt.xticks(rotation=45 , ticks = list(q3s_freqs.keys()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()


colors_q8 = sns.color_palette("coolwarm", len(q8_vocab))
q8s = np.array([q8_encoder(i) for i in q8])
q8s_freqs = np.unique(q8s , return_counts  = True)
q8s_freqs = {i[0]:i[1] for i in zip(q8s_freqs[0] , q8s_freqs[1])}
plt.figure(figsize=(12, 6))
plt.bar([q8_itos[i] for i in list(q8s_freqs.keys())] , q8s_freqs.values() , color=colors_q8, edgecolor='grey')
plt.title('Q8 Frequencies', fontsize=16, weight='bold')
plt.xlabel('Q8', fontsize=12, labelpad=10)
plt.ylabel('Frequency', fontsize=12, labelpad=10)
plt.xticks(rotation=45 , ticks = list(q8s_freqs.keys()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Conclusion: Sequences and Q3 do not present much imbalance between classes. Q8 is highly unbalanced, with I
# being almost not-present

# %%
# Statistics on Bigram Frequencies

q3_pairs = {f"{i1}-{i2}":0 for i1 in list(q3_vocab) for i2 in list(q3_vocab)}
colors_q3_pairs = sns.color_palette("coolwarm", len(q3_pairs))
q3_all = "".join(q3)
for i in zip(q3_all , q3_all[1:]):
  q3_pairs[f"{i[0]}-{i[1]}"] +=1
plt.figure(figsize=(12, 6))
bars = plt.bar(q3_pairs.keys(), q3_pairs.values(), color=colors_q3_pairs, edgecolor='grey')
plt.title("Q3 Pairs Relations", fontsize=16, weight='bold')
plt.xlabel("Pairs", fontsize=12, labelpad=10)
plt.ylabel("Absolute Frequency", fontsize=12, labelpad=10)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()


q8_pairs = {f"{i1}-{i2}":0 for i1 in list(q8_vocab) for i2 in list(q8_vocab)}
colors_q8_pairs = sns.color_palette("coolwarm", len(q8_pairs))
q8_all = "".join(q8)
for i in zip(q8_all , q8_all[1:]):
  q8_pairs[f"{i[0]}-{i[1]}"] +=1
plt.figure(figsize=(12, 6))
bars = plt.bar(q8_pairs.keys(), q8_pairs.values(), color=colors_q8_pairs, edgecolor='grey')
plt.title("Q8 Pairs Relations", fontsize=16, weight='bold')
plt.xlabel("Pairs", fontsize=12, labelpad=10)
plt.ylabel("Absolute Frequency", fontsize=12, labelpad=10)
plt.xticks(rotation=90, ha='right', fontsize=5)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Conclusion: Equipairs dominate the distribution. Highly unbalanced.

# %% [markdown]
# ## Datasets & Dataloaders

# %%
# Torchification
X = torch.tensor(seqs , device=device)
Y_q3 = torch.tensor(q3s , device=device)
Y_q8 = torch.tensor(q8s , device=device)
data_dict = {'X':X , 'Y_q3':Y_q3, 'Y_q8':Y_q8}
torch.save(data_dict , 'notoken_data_dictionary')

print(f'X shape: {X.shape} | Y_q3 shape: {Y_q3.shape} | Y_q8 shape: {Y_q8.shape}')
# Out:
# X shape: torch.Size([13473, 245]) | Y_q3 shape: torch.Size([13473, 245]) | Y_q8 shape: torch.Size([13473, 245])

# %%
# Custom Dataset & Dataloader

class CustomDataset(Dataset):
    """This is the class for creating a custom DataSet given two tensors"""
    def __init__(self, X, y):
        self.X = X
        self.y = y
    def __len__(self):
        return len(self.y)
    def __getitem__(self,idx):
        return self.X[idx], self.y[idx]

def intialise_loaders(X_train , y_train , X_val , y_val , batch_size):
    """This function creates two dataloader given two numpy arrays"""
    train_dataset = CustomDataset(X = X_train , y = y_train)
    val_dataset = CustomDataset(X = X_val , y = y_val)
    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
    return train_dataloader, val_dataloader

# %% [markdown]
# # Models

# %% [markdown]
# ## Transformer

# %%
# Hyperparameters
batch_size = 256
context_size = max_len+2
max_iters = 15 # epochs
eval_interval = 1 # Estimate loss each x
lr = 3e-3
n_emb = int(64) # embedding dimension
vocab_size = len(seq_vocab)
q3_vocab_size = len(q3_vocab)
q8_vocab_size = len(q8_vocab)
n_head = int(2)
ff_multiplier = 16 # Multiplies the number of units in the hidden feed forward
n_blocks = int(4)
dropout = 0.4
patience = 3
md = 0.05 # min delta
fact = 0.1 # reduction on plateau
b1 = 0.9
b2 = 0.999

# %%
# Transformer Model

class ProteinTransformer(nn.Module):
    def __init__(self , vs , n_emb , n_head , ff_multiplier , n_blocks , dropout):
        super().__init__()
        self.enc_token_embeddings_table = nn.Embedding(vocab_size , n_emb , device=device)
        self.enc_post_embeddings_table = nn.Embedding(context_size , n_emb , device=device)
        self.dec_token_embeddings_table = nn.Embedding(vs , n_emb , device=device)
        self.dec_post_embeddings_table = nn.Embedding(context_size , n_emb , device=device)
        self.transformer = nn.Transformer(d_model=n_emb , nhead=n_head , dim_feedforward=ff_multiplier ,
                                          num_encoder_layers=n_blocks , num_decoder_layers=n_blocks ,
                                          dropout=dropout , batch_first=True)
        self.lm_head = nn.Linear(n_emb , vs , device=device)

    def forward(self , x1 , x2):
        # Encoder's Input
        x1 = self.enc_token_embeddings_table(x1) + self.enc_post_embeddings_table(torch.arange(x1.shape[-1] , device=device))
        # Decoder's Input
        x2 = self.dec_token_embeddings_table(x2) + self.dec_post_embeddings_table(torch.arange(x2.shape[-1] , device=device))
        # Triangulation Masking for Masked Attention
        mask = torch.tril(torch.ones(x2.shape[-2] , x2.shape[-2] , device = device))
        x = self.transformer(x1 , x2 , tgt_mask = mask)
        logits = self.lm_head(x)
        return logits

    def inference(self , x , enc):
         # This method allows for the input of a sequence of aminoacids, cropps it or pads it, encodes it and predicts
         # the structure of it

        # Number of structure tokens to predict (Structure Len == Sequence Length)
        iters = len(x)

        # Adjusting length
        if len(x) < context_size-2:
          # Padding
            x = ['<' + x + '>' + '.'*(context_size-len(x)-2)] # Adding SOS & EOS & Padding
            batches = 1
            idx = torch.full((batches, context_size), enc('.')[0], dtype=torch.int , device=device) # Prediction (initially empty)
            idx[0,0] = enc('<')[0] # Start of the sequence
            idx[-1,-1] = enc('<')[0] # End of Sequence

        elif len(x) > context_size-2:
          # Cropping
            x_1 = [x[i-context_size+1:i] for i in range(context_size-1 , len(x) , context_size)]
            x_2 = x[context_size * (int(len(x)/context_size)) : len(x)]
            x_2 = [x_2 + '>' + '.'*(context_size-len(x_2)-1)][0]
            x = [x_1[i] + '.' if i != 0 else '<' + x_1[i] for i in range(len(x_1))]
            x.append(x_2)
            batches = len(x)
            idx = torch.full((batches, context_size), enc('.')[0], dtype=torch.int , device=device)
            idx[:,0] = enc('<')[0]

        else:
          # Exact Legnth
            x = ['<' + x + '>']
            batches = 1
            idx = torch.full((batches, context_size), enc('.')[0], dtype=torch.int , device=device)
            idx[0,0] = enc('<')[0] # Start of the sequence
            idx[-1,-1] = enc('<')[0] # End of Sequence

        # Encoding & Torchification
        x = torch.tensor([enc(i) for i in x] , device=device)

        # Inference
        for p in range(context_size-1):
            logits = self(x , idx) # Foward pass
            B,T,C = logits.shape
            logits = logits[:,p,:] # Extracting next token probs
            probs = F.softmax(logits,dim=-1) # Converting to probs

            # Sampling from distribution
            idx_next = torch.multinomial(probs , num_samples=1)

            # Reshaping as necessary
            B_id,C_id = idx.shape
            B_next,C_next = idx_next.shape
            idx_next = idx_next.view(B_id,C_next)
            idx[:,p+1] = idx_next[:,0] # Appending new token

        return idx

# %%
# Early Stopper Class (Extracted from Tutorial)
class EarlyStopper:
    def __init__(self, patience=3, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.min_validation_loss = np.inf

    def early_stop(self, validation_loss):
        if validation_loss < self.min_validation_loss:
            self.min_validation_loss = validation_loss
            self.counter = 0
        elif validation_loss > (self.min_validation_loss + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False



# Training Class
class Training:
    def __init__(self , data , model , hyperparams , vocab_dict , loss_func , verbose=False , valid = True):
        # Data Loaders
        if valid:
          self.train_loader , self.val_loader = intialise_loaders(data['x_train'] , data['y_train'] ,
                                                                  data['x_val'] , data['y_val'] , hyperparams['batch_size'])
        else:
          self.train_loader , self.val_loader = intialise_loaders(data['x_train'] , data['y_train'] ,
                                                                  data['x_train'] , data['y_train'] , hyperparams['batch_size'])
          self.val_loader = 0

        self.model = model
        self.optimizer = torch.optim.AdamW(model.parameters() , lr = hyperparams['lr'] , betas = (hyperparams['b1'] , hyperparams['b2']))
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, mode='min', factor=hyperparams['factor'], patience=hyperparams['patience'])
        self.hist_loss = {'train':[] , 'val':[]} # Historical Losses
        self.hist_acc = {'train':[] , 'val':[]} # Historical Accuracies
        self.hist_pres = {'train':[] , 'val':[]} # Historical Presicion
        self.hist_f1 = {'train':[] , 'val':[]} # Historical F1
        self.times = [] # Historical Epoch times
        self.hyper = hyperparams # Hyperparameter dictionary
        self.vocab = vocab_dict # stoi
        self.loss_func = loss_func
        self.early = EarlyStopper(patience = self.hyper['patience'] , min_delta = self.hyper['min_delta'])
        self.verbose = verbose

    def __call__(self, *args, **kwargs):
      # Training loop
      for i in range(self.hyper['epochs']):
            t = time.time()
            lossi = 0
            acci = 0
            all_preds = []
            all_targets = []
            for batch , (X_i,y_i) in enumerate(self.train_loader):
              # Foward Pass
                y_in = y_i[:,:-1] # Input to Decoder
                y_out = y_i[:,1:] # Labels
                X_i = X_i[:,:-1] # Input to Encoder
                logits = self.model(X_i,y_in)
                probs = F.softmax(logits , dim=-1)
                B,T,C = logits.shape

                # Metrics & Loss
                loss = self.loss_func(logits.view(B*T,C) , y_out.contiguous().view(B*T))
                acc = (torch.argmax(probs , dim=-1) == y_out).float().mean()
                all_preds.extend(torch.argmax(probs , dim=-1).view(-1).cpu().numpy())
                all_targets.extend(y_out.contiguous().view(-1).cpu().numpy())
                lossi += loss.item()
                acci += acc.item()

                # Backward Pass & Update
                self.optimizer.zero_grad(set_to_none=True)
                loss.backward()
                self.optimizer.step()

            # Update of historical data
            self.hist_loss['train'].append(lossi/len(self.train_loader))
            self.hist_acc['train'].append(acci/len(self.train_loader))
            self.hist_pres['train'].append(precision_score(all_targets , all_preds , average='weighted' , zero_division=1))
            self.hist_f1['train'].append(f1_score(all_targets , all_preds , average='weighted' , zero_division=1))
            if self.verbose:
                print(f'Epoch: {i+1}/{self.hyper["epochs"]} | Training Loss: {self.hist_loss["train"][-1]:.5f} | Training Accuracy: {self.hist_acc["train"][-1]:.5f} |'
                      f'Training Precision: {self.hist_pres["train"][-1]:.5f} | Training F1-Score: {self.hist_f1["train"][-1]:.5f}')

            if i % self.hyper['eval_int'] == 0 and isinstance(self.val_loader , int) == False:
              # Validation Evaluation
                lossi = 0
                acci = 0
                all_preds = []
                all_targets = []
                for batch , (X_i,y_i) in enumerate(self.val_loader):
                  # Foward Pass
                    y_in = y_i[:,:-1]
                    y_out = y_i[:,1:]
                    X_i = X_i[:,:-1]
                    logits = self.model(X_i,y_in)
                    probs = F.softmax(logits , dim=-1)
                    B,T,C = logits.shape

                  # Metrics & Loss
                    loss = self.loss_func(logits.view(B*T,C),y_out.contiguous().view(B*T))
                    lossi += loss.item()
                    acc = (torch.argmax(probs , dim=-1) == y_out).float().mean()
                    acci += acc.item()
                    all_preds.extend(torch.argmax(probs , dim=-1).view(-1).cpu().numpy())
                    all_targets.extend(y_out.contiguous().view(-1).cpu().numpy())

                # Update Historical Data
                self.hist_acc['val'].append(acci/len(self.val_loader))
                self.hist_loss['val'].append(lossi/len(self.val_loader))
                self.hist_pres['val'].append(precision_score(all_targets , all_preds , average='weighted' , zero_division=1))
                self.hist_f1['val'].append(f1_score(all_targets , all_preds , average='weighted' , zero_division=1))
                # Early Stop Mechanism
                stop = self.early.early_stop(1/self.hist_f1['val'][-1])
                if stop:
                  if self.verbose:
                    print(f'Patience surpassed --> Stopping')
                  break
                self.scheduler.step(1/self.hist_f1['val'][-1])
                if self.verbose:
                    print(f'Epoch: {i+1}/{self.hyper["epochs"]} | Validation Loss: {self.hist_loss["val"][-1]:.5f} | '
                          f'Validation Accuracy: {self.hist_acc["val"][-1]:.5f} | Learning Rate: {self.optimizer.param_groups[0]["lr"]} | '
                          f'Validation Precision: {self.hist_pres["val"][-1]:.5f} | Validation F1-Score: {self.hist_f1["val"][-1]:.5f}')
            self.times.append(time.time()-t)

# %% [markdown]
# ## Evaluation functions

# %%
def plot_learning_curves(tr):
    plt.figure(figsize=(8, 5))
    plt.plot(tr.hist_loss['train'], label='Training Loss')
    plt.plot(tr.hist_loss['val'], label='Validation Loss')
    plt.title('Learning Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

    plt.figure(figsize=(8, 5))
    plt.plot(tr.hist_acc['train'], label='Training Accuracy')
    plt.plot(tr.hist_acc['val'], label='Validation Accuracy')
    plt.title('Learning Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()
    plt.show()

# %%
def plot_confusion_matrix(model, tr, itos, stoi, title='Confusion Matrix'):
    model.eval()

    # Initialize lists to store all predictions and labels
    all_preds = []
    all_labels = []

    # Get the padding index to exclude it from the confusion matrix
    pad_idx = stoi['.']

    with torch.no_grad():
        for batch, (X_i, y_i) in enumerate(tr.val_loader):
            y_in = y_i[:, :-1]
            y_out = y_i[:, 1:]
            X_i = X_i[:, :-1]
            logits = model(X_i, y_in)
            preds = torch.argmax(logits, dim=-1)

            # Flatten predictions and labels using reshape instead of view
            preds_flat = preds.reshape(-1)
            y_out_flat = y_out.reshape(-1)

            # Create a mask to exclude padding tokens in both labels and predictions
            mask = (y_out_flat != pad_idx) & (preds_flat != pad_idx)

            # Apply the mask and move tensors to CPU
            preds_flat = preds_flat[mask].cpu()
            y_out_flat = y_out_flat[mask].cpu()

            # Append to the lists
            all_preds.append(preds_flat)
            all_labels.append(y_out_flat)

    # Concatenate all predictions and labels
    y_pred = torch.cat(all_preds)
    y_true = torch.cat(all_labels)

    # Convert to numpy arrays if they aren't already
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # Dynamically retrieve the padding index, default to -1 if `.` is not found
    padding_index = stoi.get('.', -1)
    ignore_index = -100

    # Exclude padding and ignore positions (where y_true == ignore_index or padding index)
    mask = (y_true != ignore_index) & (y_true != padding_index)
    y_true_filtered = y_true[mask]
    y_pred_filtered = y_pred[mask]

    # Verify that y_true_filtered and y_pred_filtered contain valid class labels
    valid_labels = sorted(set(y_true_filtered) | set(y_pred_filtered))
    print(f"Valid labels after filtering: {valid_labels}")

    # Generate confusion matrix with the filtered data
    cm = confusion_matrix(y_true_filtered, y_pred_filtered, labels=valid_labels)
    plt.gcf().set_size_inches(12, 10)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=[itos[label] for label in valid_labels],
                yticklabels=[itos[label] for label in valid_labels])
    plt.title(title)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    # Save the confusion matrix plot before showing it
    #confusion_matrix_path = os.path.join(full_folder_path, 'confusion_matrix.png')
    #plt.savefig(confusion_matrix_path)
    #print(f"Confusion matrix plot saved at: {confusion_matrix_path}")

    # Display the plot
    plt.show()

# %% [markdown]
# ## Initial Predictions

# %% [markdown]
# #### Q3

# %%
# Splitting Data
# Validation Set
vix = torch.randperm(X.shape[0])[:int(X.shape[0]*.15)] # Validation Indices
x_val = X[vix,:]
y_val = Y_q3[vix,:]

# Training Set
ix = torch.tensor(list(set(range(X.shape[0])) - set([i.item() for i in vix]))) # Training Indices
x_tr = X[ix]
y_tr = Y_q3[ix]

# Preparing Inputs
data = {'x_train':x_tr , 'y_train':y_tr , 'x_val':x_val , 'y_val':y_val}
hy =  {'batch_size':batch_size , 'epochs':15 , 'lr':lr , 'eval_int':eval_interval , 'patience':patience , 'factor':fact , 'min_delta':md , 'b1':b1 , 'b2':b2}
pr = ProteinTransformer(q3_vocab_size , n_emb , n_blocks , ff_multiplier , n_head , dropout)
pr.to(device)
loss_func = nn.CrossEntropyLoss(ignore_index=q3_stoi[('.', '.')])
print(f"Model's trainable parameters: {sum([i.numel() for i in pr.parameters()])}")

# Training Loop
tr = Training(data , pr , hy , q3_stoi , loss_func , verbose=True)
tr()
# Out:
# Model's trainable parameters: 143558
# Epoch: 1/15 | Training Loss: 0.66611 | Training Accuracy: 0.51912 |Training Precision: 0.53836 | Training F1-Score: 0.42060
# Epoch: 1/15 | Validation Loss: 1.30366 | Validation Accuracy: 0.56350 | Learning Rate: 0.003 | Validation Precision: 0.71728 | Validation F1-Score: 0.45837
# Epoch: 2/15 | Training Loss: 0.53039 | Training Accuracy: 0.55309 |Training Precision: 0.72271 | Training F1-Score: 0.44836
# Epoch: 2/15 | Validation Loss: 1.29667 | Validation Accuracy: 0.56393 | Learning Rate: 0.003 | Validation Precision: 0.72571 | Validation F1-Score: 0.46280
# Epoch: 3/15 | Training Loss: 0.52415 | Training Accuracy: 0.55295 |Training Precision: 0.72184 | Training F1-Score: 0.44977
# Epoch: 3/15 | Validation Loss: 1.29549 | Validation Accuracy: 0.56373 | Learning Rate: 0.003 | Validation Precision: 0.72022 | Validation F1-Score: 0.46077
# Epoch: 4/15 | Training Loss: 0.52076 | Training Accuracy: 0.55297 |Training Precision: 0.71505 | Training F1-Score: 0.44693
# Epoch: 4/15 | Validation Loss: 1.30271 | Validation Accuracy: 0.56366 | Learning Rate: 0.003 | Validation Precision: 0.71947 | Validation F1-Score: 0.46166
# Epoch: 5/15 | Training Loss: 0.51905 | Training Accuracy: 0.55329 |Training Precision: 0.71661 | Training F1-Score: 0.44759
# Epoch: 5/15 | Validation Loss: 1.29515 | Validation Accuracy: 0.56311 | Learning Rate: 0.003 | Validation Precision: 0.71556 | Validation F1-Score: 0.45994
# Epoch: 6/15 | Training Loss: 0.51749 | Training Accuracy: 0.55317 |Training Precision: 0.71508 | Training F1-Score: 0.44698
# Epoch: 6/15 | Validation Loss: 1.29950 | Validation Accuracy: 0.56343 | Learning Rate: 0.00030000000000000003 | Validation Precision: 0.71519 | Validation F1-Score: 0.45983
# Epoch: 7/15 | Training Loss: 0.51624 | Training Accuracy: 0.55335 |Training Precision: 0.71360 | Training F1-Score: 0.44635
# Epoch: 7/15 | Validation Loss: 1.29464 | Validation Accuracy: 0.56334 | Learning Rate: 0.00030000000000000003 | Validation Precision: 0.71291 | Validation F1-Score: 0.45888
# Epoch: 8/15 | Training Loss: 0.51590 | Training Accuracy: 0.55326 |Training Precision: 0.71271 | Training F1-Score: 0.44594
# Epoch: 8/15 | Validation Loss: 1.29430 | Validation Accuracy: 0.56352 | Learning Rate: 0.00030000000000000003 | Validation Precision: 0.71248 | Validation F1-Score: 0.45870
# Epoch: 9/15 | Training Loss: 0.51590 | Training Accuracy: 0.55308 |Training Precision: 0.71234 | Training F1-Score: 0.44580
# Epoch: 9/15 | Validation Loss: 1.29521 | Validation Accuracy: 0.56345 | Learning Rate: 0.00030000000000000003 | Validation Precision: 0.71286 | Validation F1-Score: 0.45882
# Epoch: 10/15 | Training Loss: 0.51543 | Training Accuracy: 0.55342 |Training Precision: 0.71181 | Training F1-Score: 0.44557
# Epoch: 10/15 | Validation Loss: 1.29479 | Validation Accuracy: 0.56395 | Learning Rate: 3.0000000000000004e-05 | Validation Precision: 0.71180 | Validation F1-Score: 0.45840
# Epoch: 11/15 | Training Loss: 0.51527 | Training Accuracy: 0.55340 |Training Precision: 0.71156 | Training F1-Score: 0.44545
# Epoch: 11/15 | Validation Loss: 1.29523 | Validation Accuracy: 0.56341 | Learning Rate: 3.0000000000000004e-05 | Validation Precision: 0.71149 | Validation F1-Score: 0.45823
# Epoch: 12/15 | Training Loss: 0.51536 | Training Accuracy: 0.55347 |Training Precision: 0.71120 | Training F1-Score: 0.44529
# Epoch: 12/15 | Validation Loss: 1.29535 | Validation Accuracy: 0.56351 | Learning Rate: 3.0000000000000004e-05 | Validation Precision: 0.71162 | Validation F1-Score: 0.45829
# Epoch: 13/15 | Training Loss: 0.51522 | Training Accuracy: 0.55322 |Training Precision: 0.71120 | Training F1-Score: 0.44530
# Epoch: 13/15 | Validation Loss: 1.29515 | Validation Accuracy: 0.56376 | Learning Rate: 3.0000000000000004e-05 | Validation Precision: 0.71162 | Validation F1-Score: 0.45834
# Epoch: 14/15 | Training Loss: 0.51526 | Training Accuracy: 0.55315 |Training Precision: 0.71119 | Training F1-Score: 0.44530
# Epoch: 14/15 | Validation Loss: 1.29519 | Validation Accuracy: 0.56351 | Learning Rate: 3.0000000000000005e-06 | Validation Precision: 0.71134 | Validation F1-Score: 0.45820
# Epoch: 15/15 | Training Loss: 0.51508 | Training Accuracy: 0.55315 |Training Precision: 0.71104 | Training F1-Score: 0.44522
# Epoch: 15/15 | Validation Loss: 1.29508 | Validation Accuracy: 0.56332 | Learning Rate: 3.0000000000000005e-06 | Validation Precision: 0.71130 | Validation F1-Score: 0.45817

# %%
# Results
plot_learning_curves(tr)
plot_confusion_matrix(pr, tr, q3_itos, q3_stoi, title='Confusion Matrix  | Q3')

# The gap between training and validation loss is alarming. It signals great overfitting
# and, also, it shows that the model has converged after  single epoch. This is more
# likely to be due to lack of data than a too small model, since the model has 140k
# params, while threre are only 9k datapoints.
# However, the validation accuracy is, despite being absolutely stagnant, better than the
# training one by a slight marging. This might be because the model is doing the correct
# predictions, but is not very confident, pushing up the loss without affecting the accuracy.
# Out:
# Valid labels after filtering: [2, 3, 4, 5]

# %% [markdown]
# #### Q8

# %%
# Splitting Data
# Validation Set
vix = torch.randperm(X.shape[0])[:int(X.shape[0]*.15)] # Validatin Indices
x_val = X[vix,:]
y_val = Y_q8[vix,:]

# Training Set
ix = torch.tensor(list(set(range(X.shape[0])) - set([i.item() for i in vix]))) # Training Indices
x_tr = X[ix]
y_tr = Y_q8[ix]

# Preparing Inputs
data = {'x_train':x_tr , 'y_train':y_tr , 'x_val':x_val , 'y_val':y_val}
hy =  {'batch_size':batch_size , 'epochs':15 , 'lr':lr , 'eval_int':eval_interval , 'patience':patience , 'factor':fact , 'min_delta':md , 'b1':b1 , 'b2':b2}
loss_func = nn.CrossEntropyLoss(ignore_index=q3_stoi[('.', '.')])
pr = ProteinTransformer(q8_vocab_size , n_emb , n_blocks , ff_multiplier , n_head , dropout)
pr.to(device)
print(f"Model's trainable parameters: {sum([i.numel() for i in pr.parameters()])}")

# Training Loop
tr = Training(data , pr , hy , q8_stoi , loss_func , verbose=True)
tr()
# Out:
# Model's trainable parameters: 144203
# Epoch: 1/15 | Training Loss: 1.12893 | Training Accuracy: 0.43408 |Training Precision: 0.35094 | Training F1-Score: 0.33632
# Epoch: 1/15 | Validation Loss: 1.93855 | Validation Accuracy: 0.48008 | Learning Rate: 0.003 | Validation Precision: 0.70498 | Validation F1-Score: 0.39701
# Epoch: 2/15 | Training Loss: 0.92399 | Training Accuracy: 0.47991 |Training Precision: 0.69113 | Training F1-Score: 0.39080
# Epoch: 2/15 | Validation Loss: 1.93364 | Validation Accuracy: 0.48049 | Learning Rate: 0.003 | Validation Precision: 0.69563 | Validation F1-Score: 0.39473
# Epoch: 3/15 | Training Loss: 0.91161 | Training Accuracy: 0.48019 |Training Precision: 0.70111 | Training F1-Score: 0.39613
# Epoch: 3/15 | Validation Loss: 1.93057 | Validation Accuracy: 0.48093 | Learning Rate: 0.003 | Validation Precision: 0.70714 | Validation F1-Score: 0.39812
# Epoch: 4/15 | Training Loss: 0.90479 | Training Accuracy: 0.48057 |Training Precision: 0.70263 | Training F1-Score: 0.39647
# Epoch: 4/15 | Validation Loss: 1.93113 | Validation Accuracy: 0.48107 | Learning Rate: 0.003 | Validation Precision: 0.70365 | Validation F1-Score: 0.39767
# Epoch: 5/15 | Training Loss: 0.89902 | Training Accuracy: 0.48059 |Training Precision: 0.70374 | Training F1-Score: 0.39702
# Epoch: 5/15 | Validation Loss: 1.93141 | Validation Accuracy: 0.48093 | Learning Rate: 0.003 | Validation Precision: 0.69796 | Validation F1-Score: 0.39652
# Epoch: 6/15 | Training Loss: 0.89275 | Training Accuracy: 0.48097 |Training Precision: 0.69380 | Training F1-Score: 0.39582
# Epoch: 6/15 | Validation Loss: 1.92641 | Validation Accuracy: 0.48160 | Learning Rate: 0.003 | Validation Precision: 0.69514 | Validation F1-Score: 0.39456
# Epoch: 7/15 | Training Loss: 0.88212 | Training Accuracy: 0.48165 |Training Precision: 0.68538 | Training F1-Score: 0.39362
# Epoch: 7/15 | Validation Loss: 1.92378 | Validation Accuracy: 0.48292 | Learning Rate: 0.003 | Validation Precision: 0.68410 | Validation F1-Score: 0.39979
# Epoch: 8/15 | Training Loss: 0.85934 | Training Accuracy: 0.48601 |Training Precision: 0.68823 | Training F1-Score: 0.40057
# Epoch: 8/15 | Validation Loss: 1.90604 | Validation Accuracy: 0.49073 | Learning Rate: 0.003 | Validation Precision: 0.70255 | Validation F1-Score: 0.40931
# Epoch: 9/15 | Training Loss: 0.81584 | Training Accuracy: 0.49548 |Training Precision: 0.69613 | Training F1-Score: 0.40981
# Epoch: 9/15 | Validation Loss: 1.88267 | Validation Accuracy: 0.50539 | Learning Rate: 0.003 | Validation Precision: 0.70270 | Validation F1-Score: 0.41981
# Epoch: 10/15 | Training Loss: 0.72934 | Training Accuracy: 0.51336 |Training Precision: 0.70695 | Training F1-Score: 0.42470
# Epoch: 10/15 | Validation Loss: 1.83584 | Validation Accuracy: 0.52605 | Learning Rate: 0.003 | Validation Precision: 0.71715 | Validation F1-Score: 0.43841
# Epoch: 11/15 | Training Loss: 0.62326 | Training Accuracy: 0.53440 |Training Precision: 0.71658 | Training F1-Score: 0.43979
# Epoch: 11/15 | Validation Loss: 1.79848 | Validation Accuracy: 0.54212 | Learning Rate: 0.003 | Validation Precision: 0.71581 | Validation F1-Score: 0.44472
# Epoch: 12/15 | Training Loss: 0.54981 | Training Accuracy: 0.54823 |Training Precision: 0.72359 | Training F1-Score: 0.45002
# Epoch: 12/15 | Validation Loss: 1.76050 | Validation Accuracy: 0.55892 | Learning Rate: 0.003 | Validation Precision: 0.72649 | Validation F1-Score: 0.45894
# Epoch: 13/15 | Training Loss: 0.45502 | Training Accuracy: 0.56766 |Training Precision: 0.73494 | Training F1-Score: 0.46595
# Epoch: 13/15 | Validation Loss: 1.72103 | Validation Accuracy: 0.57768 | Learning Rate: 0.003 | Validation Precision: 0.74595 | Validation F1-Score: 0.47784
# Epoch: 14/15 | Training Loss: 0.37683 | Training Accuracy: 0.58379 |Training Precision: 0.75144 | Training F1-Score: 0.48309
# Epoch: 14/15 | Validation Loss: 1.69808 | Validation Accuracy: 0.59124 | Learning Rate: 0.003 | Validation Precision: 0.75565 | Validation F1-Score: 0.49062
# Epoch: 15/15 | Training Loss: 0.32119 | Training Accuracy: 0.59448 |Training Precision: 0.76488 | Training F1-Score: 0.49635
# Epoch: 15/15 | Validation Loss: 1.67525 | Validation Accuracy: 0.60114 | Learning Rate: 0.003 | Validation Precision: 0.76826 | Validation F1-Score: 0.50326

# %%
# Results
plot_learning_curves(tr)
plot_confusion_matrix(pr, tr, q8_itos, q8_stoi, title='Confusion Matrix  | Q8')

# The loss evolution is somewhat better than the one on Q3, however, it still signals
# great overfitting, with the training loss approach zero, while the validation loss
# being higher than 1.5.
# This does not match well with the validation accuracy being higher than the training
# one and it improving greatly. This might signal that the model is getting the right
# predictions despite it being not very confident, pushing up the loss.
# Out:
# Valid labels after filtering: [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %% [markdown]
# ## Hyperparameter Tunning w/ Bayesian Optmization

# %%
# K-Fold CV Splitting

datasets = {'train':[] , 'val':[]} # Dictionary to host the splits
k = KFold(n_splits=3, shuffle=True, random_state=42)

# Loop to extract the splits
for tr,vl in k.split(np.array([i for i in range(X.shape[0])])):
    tr = torch.tensor(tr , dtype=torch.int , device=device)
    vl = torch.tensor(vl , dtype=torch.int , device=device)
    datasets['train'].append(tr)
    datasets['val'].append(vl)

# %%
# Bayes Optimization Search Hyperparams

# Bounded region of parameter space
pbounds = {'lr' : (10e-5, 0.1) , 'batch_size' : (32,256) , 'n_emb' : (4,256) , 'n_head' : (1,8) ,
           'ff_multiplier' : (1,32) , 'n_blocks' : (1,8) , 'dropout' : (.1,.5) , 'patience' : (0,3) ,
           'factor' : (0.01,.5) , 'min_delta' : (0.01,0.1) , 'b1':(0.9,0.999) , 'b2':(0.95,0.9999)}

# Bayes Search Values
init_p = 10
n_iter = 5

# %% [markdown]
# #### Q3

# %%
def bayes_opt_func(lr , batch_size , n_emb , n_head , ff_multiplier , n_blocks , dropout , patience , factor , min_delta , b1 , b2):
  """This function has to be maximized by the Bayesian Optimization"""

  # Extracting hyperparams from inputs (Inputs might be continues, but some hyperparams must be ints)
  n_head = int(n_head)
  n_emb = int(n_emb - n_emb % n_head) # Keeps required ratio
  ff_multiplier = int(ff_multiplier)
  n_blocks = int(n_blocks)
  batch_size = int(batch_size)
  patience = int(patience)

  # Historical F1s (Function will maximize F1, not loss)
  f1s = []

  # Cross-Validation
  for i in range(len(datasets['train'])):
    model = ProteinTransformer(q3_vocab_size , n_emb , n_head , ff_multiplier , n_blocks , dropout)
    model.to(device)
    data = {'x_train':X[datasets['train'][i],:] , 'y_train':Y_q3[datasets['train'][i],:] ,
            'x_val':X[datasets['val'][i],:] , 'y_val':Y_q3[datasets['val'][i],:]} # Changed 'y_val':X[...] to 'y_val':Y_q3[...] to ensure correct validation data
    hy = {'batch_size':batch_size , 'epochs':10 , 'lr':lr , 'eval_int':eval_interval , 'patience':patience ,
          'factor':factor , 'min_delta':min_delta, 'b1':b1 , 'b2':b2}
    loss_func = nn.CrossEntropyLoss(ignore_index=q3_stoi['.'])
    tr = Training(data , model , hy , q3_stoi , loss_func , verbose=False)
    tr()

    f1s.append(tr.hist_f1['val'][-1])

  # Returning mean F1 acros different splits
  return np.mean(f1s)

# %%
# CV Search

optimizer = BayesianOptimization(
    f=bayes_opt_func,
    pbounds=pbounds,
    random_state=seed,
)

optimizer.maximize(
    init_points = init_p,
    n_iter = n_iter,
)
# Out:
# |   iter    |  target   |    b1     |    b2     | batch_... |  dropout  |  factor   | ff_mul... |    lr     | min_delta | n_blocks  |   n_emb   |  n_head   | patience  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 1         | 0.4508    | 0.9764    | 0.951     | 173.9     | 0.3995    | 0.2543    | 7.969     | 0.01989   | 0.07845   | 2.184     | 26.26     | 5.798     | 2.86      |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 2         | 0.1243    | 0.9004    | 0.9756    | 214.0     | 0.345     | 0.3637    | 10.05     | 0.09179   | 0.07431   | 4.798     | 39.83     | 3.613     | 2.022     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 3         | 0.1243    | 0.9437    | 0.9717    | 170.4     | 0.3053    | 0.3287    | 19.63     | 0.08054   | 0.05695   | 7.361     | 84.45     | 1.633     | 0.9021    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 4         | 0.1243    | 0.9113    | 0.9914    | 42.5      | 0.3505    | 0.2783    | 26.4      | 0.01997   | 0.08712   | 3.462     | 194.2     | 3.072     | 2.652     |
# | 5         | 0.1246    | 0.9322    | 0.9582    | 119.9     | 0.1374    | 0.4123    | 5.686     | 0.03847   | 0.09498   | 7.913     | 119.0     | 6.783     | 0.7541    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 6         | 0.1293    | 0.9591    | 0.9951    | 151.7     | 0.3361    | 0.02925   | 12.07     | 0.008053  | 0.03749   | 3.315     | 199.0     | 1.28      | 1.288     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 7         | 0.1243    | 0.9312    | 0.9818    | 109.6     | 0.1172    | 0.4412    | 24.66     | 0.08782   | 0.04758   | 5.239     | 133.4     | 5.185     | 0.7866    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 8         | 0.1194    | 0.9298    | 0.9513    | 99.89     | 0.1968    | 0.2832    | 18.53     | 0.04757   | 0.03635   | 1.45      | 250.7     | 3.378     | 1.485     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 9         | 0.125     | 0.9967    | 0.972     | 103.3     | 0.3079    | 0.2933    | 27.47     | 0.006903  | 0.05181   | 6.474     | 185.1     | 5.102     | 0.1113    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 10        | 0.4704    | 0.9347    | 0.9781    | 99.14     | 0.3049    | 0.34      | 5.935     | 0.005143  | 0.0404    | 1.756     | 49.08     | 7.201     | 1.096     |
# | 11        | 0.4462    | 0.9723    | 0.9502    | 131.8     | 0.2753    | 0.2145    | 3.015     | 0.0277    | 0.0602    | 2.534     | 19.8      | 6.014     | 2.287     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 12        | 0.4456    | 0.9675    | 0.9526    | 174.7     | 0.1767    | 0.3411    | 6.104     | 0.006962  | 0.02872   | 4.762     | 26.49     | 7.08      | 1.077     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 13        | 0.1243    | 0.9732    | 0.9514    | 62.51     | 0.3612    | 0.2987    | 30.93     | 0.08181   | 0.0886    | 4.075     | 20.8      | 5.873     | 0.01132   |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 14        | 0.1243    | 0.9612    | 0.9898    | 159.0     | 0.2844    | 0.157     | 26.68     | 0.07095   | 0.06062   | 6.666     | 7.183     | 1.761     | 0.3326    |
# | 15        | 0.1243    | 0.9158    | 0.979     | 123.5     | 0.1735    | 0.3558    | 1.601     | 0.05401   | 0.0379    | 6.89      | 44.67     | 4.074     | 2.63      |
# =========================================================================================================================================================================

# %% [markdown]
# #### Q8

# %%
def bayes_opt_func(lr , batch_size , n_emb , n_head , ff_multiplier , n_blocks , dropout , patience , factor , min_delta , b1 , b2):
  """This function has to be maximized by the Bayesian Optimization"""

  # Extracting hyperparams from inputs (Inputs might be continues, but some hyperparams must be ints)
  n_head = int(n_head)
  n_emb = int(n_emb - n_emb % n_head) # Keeps required ratio
  ff_multiplier = int(ff_multiplier)
  n_blocks = int(n_blocks)
  batch_size = int(batch_size)
  patience = int(patience)

  # Historical F1s (Function will maximize F1, not loss)
  f1s = []

  # Cross-Validation
  for i in range(len(datasets['train'])):
    model = ProteinTransformer(q8_vocab_size , n_emb , n_head , ff_multiplier , n_blocks , dropout)
    model.to(device)
    data = {'x_train':X[datasets['train'][i],:] , 'y_train':Y_q8[datasets['train'][i],:] ,
            'x_val':X[datasets['val'][i],:] , 'y_val':Y_q8[datasets['val'][i],:]} # Changed 'y_val':X[...] to 'y_val':Y_q3[...] to ensure correct validation data
    hy = {'batch_size':batch_size , 'epochs':15 , 'lr':lr , 'eval_int':eval_interval ,
          'patience':patience , 'factor':factor , 'min_delta':min_delta, 'b1':b1 , 'b2':b2}
    loss_func = nn.CrossEntropyLoss(ignore_index=q8_stoi['.'])
    tr = Training(data , model , hy , q8_stoi , loss_func , verbose=False)
    tr()

    f1s.append(tr.hist_f1['val'][-1])

  # Returning mean F1 acros different splits
  return np.mean(f1s)

# %%
# CV Search

optimizer = BayesianOptimization(
    f=bayes_opt_func,
    pbounds=pbounds,
    random_state=seed,
)

optimizer.maximize(
    init_points = init_p,
    n_iter = n_iter,
)
# Out:
# |   iter    |  target   |    b1     |    b2     | batch_... |  dropout  |  factor   | ff_mul... |    lr     | min_delta | n_blocks  |   n_emb   |  n_head   | patience  |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 1         | 0.4188    | 0.9764    | 0.951     | 173.9     | 0.3995    | 0.2543    | 7.969     | 0.01989   | 0.07845   | 2.184     | 26.26     | 5.798     | 2.86      |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 2         | 0.07259   | 0.9004    | 0.9756    | 214.0     | 0.345     | 0.3637    | 10.05     | 0.09179   | 0.07431   | 4.798     | 39.83     | 3.613     | 2.022     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 3         | 0.07265   | 0.9437    | 0.9717    | 170.4     | 0.3053    | 0.3287    | 19.63     | 0.08054   | 0.05695   | 7.361     | 84.45     | 1.633     | 0.9021    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 4         | 0.07259   | 0.9113    | 0.9914    | 42.5      | 0.3505    | 0.2783    | 26.4      | 0.01997   | 0.08712   | 3.462     | 194.2     | 3.072     | 2.652     |
# | 5         | 0.07259   | 0.9322    | 0.9582    | 119.9     | 0.1374    | 0.4123    | 5.686     | 0.03847   | 0.09498   | 7.913     | 119.0     | 6.783     | 0.7541    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 6         | 0.07303   | 0.9591    | 0.9951    | 151.7     | 0.3361    | 0.02925   | 12.07     | 0.008053  | 0.03749   | 3.315     | 199.0     | 1.28      | 1.288     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 7         | 0.07259   | 0.9312    | 0.9818    | 109.6     | 0.1172    | 0.4412    | 24.66     | 0.08782   | 0.04758   | 5.239     | 133.4     | 5.185     | 0.7866    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 8         | 0.1292    | 0.9298    | 0.9513    | 99.89     | 0.1968    | 0.2832    | 18.53     | 0.04757   | 0.03635   | 1.45      | 250.7     | 3.378     | 1.485     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 9         | 0.07472   | 0.9967    | 0.972     | 103.3     | 0.3079    | 0.2933    | 27.47     | 0.006903  | 0.05181   | 6.474     | 185.1     | 5.102     | 0.1113    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 10        | 0.4408    | 0.9347    | 0.9781    | 99.14     | 0.3049    | 0.34      | 5.935     | 0.005143  | 0.0404    | 1.756     | 49.08     | 7.201     | 1.096     |
# | 11        | 0.07259   | 0.95      | 0.9925    | 109.3     | 0.24      | 0.1117    | 13.84     | 0.06473   | 0.04851   | 2.098     | 38.03     | 6.788     | 1.433     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 12        | 0.07295   | 0.9936    | 0.9811    | 62.26     | 0.4958    | 0.01612   | 23.67     | 0.05873   | 0.05648   | 2.769     | 22.31     | 1.216     | 1.853     |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 13        | 0.07795   | 0.9726    | 0.9681    | 236.7     | 0.4251    | 0.2123    | 27.55     | 0.06529   | 0.08491   | 4.755     | 71.84     | 7.456     | 0.6281    |
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.num_heads is odd
#   warnings.warn(
# | 14        | 0.07259   | 0.9247    | 0.9969    | 84.83     | 0.3432    | 0.4576    | 10.41     | 0.07457   | 0.07713   | 4.306     | 104.0     | 7.875     | 0.2124    |
# | 15        | 0.07259   | 0.9308    | 0.9779    | 76.16     | 0.4296    | 0.4671    | 22.53     | 0.0227    | 0.04719   | 6.07      | 216.1     | 6.72      | 1.402     |
# =========================================================================================================================================================================

# %% [markdown]
# ## Model w/ Optimized Hyperparams

# %% [markdown]
# #### Q3

# %%
# Preparing Inputs
data = {'x_train':X , 'y_train':Y_q3 , 'x_val':X , 'y_val':Y_q3}
hy = {'batch_size':128 , 'epochs':15 , 'lr':0.005 , 'eval_int':eval_interval ,
      'patience':1 , 'factor':0.35 , 'min_delta':0.05 , 'b1':0.935 , 'b2':0.978}
pr = ProteinTransformer(q3_vocab_size , n_emb=64 , n_head=8 ,
                        ff_multiplier=6 , n_blocks=2 , dropout=0.3)
pr.to(device)
loss_func = nn.CrossEntropyLoss(ignore_index=q3_stoi['.'])
print(f"Model's trainable parameters: {sum([i.numel() for i in pr.parameters()])}")

# Training Loop
tr = Training(data , pr , hy , q3_stoi , loss_func , verbose = True , valid = False)
tr()
# Saving Model
torch.save(pr.state_dict(), 'Q3_protein_transformer_notoken.pth')
# Out:
# Model's trainable parameters: 138398
# Epoch: 1/15 | Training Loss: 0.57284 | Training Accuracy: 0.54283 |Training Precision: 0.62804 | Training F1-Score: 0.43595
# Epoch: 2/15 | Training Loss: 0.51764 | Training Accuracy: 0.55603 |Training Precision: 0.70749 | Training F1-Score: 0.44605
# Epoch: 3/15 | Training Loss: 0.50999 | Training Accuracy: 0.55521 |Training Precision: 0.71496 | Training F1-Score: 0.44981
# Epoch: 4/15 | Training Loss: 0.49665 | Training Accuracy: 0.55722 |Training Precision: 0.72641 | Training F1-Score: 0.45543
# Epoch: 5/15 | Training Loss: 0.47355 | Training Accuracy: 0.56103 |Training Precision: 0.71402 | Training F1-Score: 0.45186
# Epoch: 6/15 | Training Loss: 0.43060 | Training Accuracy: 0.56763 |Training Precision: 0.71921 | Training F1-Score: 0.45810
# Epoch: 7/15 | Training Loss: 0.37236 | Training Accuracy: 0.57804 |Training Precision: 0.72676 | Training F1-Score: 0.46759
# Epoch: 8/15 | Training Loss: 0.33410 | Training Accuracy: 0.58653 |Training Precision: 0.74265 | Training F1-Score: 0.48109
# Epoch: 9/15 | Training Loss: 0.30193 | Training Accuracy: 0.59247 |Training Precision: 0.75239 | Training F1-Score: 0.49286
# Epoch: 10/15 | Training Loss: 0.28443 | Training Accuracy: 0.59523 |Training Precision: 0.76836 | Training F1-Score: 0.50169
# Epoch: 11/15 | Training Loss: 0.26764 | Training Accuracy: 0.59910 |Training Precision: 0.77550 | Training F1-Score: 0.50833
# Epoch: 12/15 | Training Loss: 0.24885 | Training Accuracy: 0.60332 |Training Precision: 0.78966 | Training F1-Score: 0.51900
# Epoch: 13/15 | Training Loss: 0.22921 | Training Accuracy: 0.60745 |Training Precision: 0.79947 | Training F1-Score: 0.52656
# Epoch: 14/15 | Training Loss: 0.21411 | Training Accuracy: 0.60997 |Training Precision: 0.80967 | Training F1-Score: 0.53402
# Epoch: 15/15 | Training Loss: 0.19770 | Training Accuracy: 0.61327 |Training Precision: 0.83119 | Training F1-Score: 0.54841

# %%
# Testing
# Creating initial model
pr = ProteinTransformer(q3_vocab_size , n_emb=64 , n_head=8 ,
                        ff_multiplier=6 , n_blocks=2 , dropout=0.3)
pr.to(device)
# Loading weights
state_dict = torch.load('/content/Q3_protein_transformer_notoken.pth')
pr.load_state_dict(state_dict)
pr.eval()

print(q3_stoi,'\n\n')
count = 0
acc_total = 0
for i in range(df_test.shape[0]):
  count += 1
  # Predicting & Decoding Structure
  pred = q3_decoder(pr.inference(list(df_test['seq'])[i] , seq_encoder).cpu().numpy().flatten()[0:len(list(df_test['sst3'])[i])])
  pred = [item for i in pred for item in (i if isinstance(i, tuple) else [i])][0:len(list(df_test['sst3'])[i])]
  final_pred = ''.join(pred)
  ground_truth = list(df_test['sst3'])[i]
  acc = [1 if i[0] == i[1] else 0 for i in zip(final_pred,ground_truth)]
  acc_perc = sum(acc)/len(acc)
  acc_total += acc_perc

  # Checking Results
  if i % 10 == 0:
    print(f'Predicted structure:\n' , final_pred)
    print(f'True structure:\n' , ground_truth)
    print(f'Accuracy: {acc_perc} \n\n')
print(f'Average Accuracy: {acc_total/count}')

# The model is greatly over predicting the EOS token, which negatively impact the
# overall accuracy. Additioanlly, it appears to be biased otwards predicting C and H,
# failing to predict almost any E. This caused the model to have an overall accuracy
# that is worse than chance.
# Out:
# <ipython-input-40-20592ea4193e>:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('/content/Q3_protein_transformer_notoken.pth')
# {'.': 0, '<': 1, '>': 2, 'C': 3, 'E': 4, 'H': 5}
#
#
# Predicted structure:
#  >CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC>>>>CCEE>EE>EE>>>>C>>>>C>E>>>>>>E>>>C>>>>>>>>>>>>>>H>>>>>>>>>>>>>>E>E>>>>>>>>>>H>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# True structure:
#  
# Accuracy: 0.3654390934844193
#
#
# Predicted structure:
#  >>>>HCEHHHHHCHHHHHCCCHHCCHHHHHHHCHHHHEHCCHHHHHHHHHHHHHCHHCHHHHCHH>CH>>>>>>>>>>>>HH>>>>>>>
# True structure:
#  CCCCCHHHCCCHHHCCHHHHHHHHHHHHHHCCCCCCCCCCCCCCHHHHCCCCHHHHHHHCCCCHHHHHHHHHHHHHHHHHHHHCCCCCC
# Accuracy: 0.33707865168539325
#
#
# Predicted structure:
#  >HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHCHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# True structure:
#  CCCCCCCHHHHHHHHHHHHHHHHHCCCCEEEEHHHHHHHCCCCCCCCCCCEEEEECCCCCCCCHHHHHHHHHHHCCCCEEEEECCCCEEEEEEEECCCCCEEEEEEEEEECCCCCCCHHHCCCCCCEEEEEECCEEEEEECHHHHHHHHHHHHHHCCCCCCHHHHHHHHHHHHHHCCCCCHHHECCCCHHHHHHHHHHHHHCHHHHHHHHCCCECHHHHCC
# Accuracy: 0.4253393665158371
#
#
# Predicted structure:
#  >>>>>C>>E>E>>EE>>>>>>>>>>>>E>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>E>>>>>>>>>>>>>>>>>>>>>E>>>>>>>>>>>>>
# True structure:
#  CCCCHHHHHHHHHHHHHHHHHHHHHHHCCCCCCEEEEEEEEEECCEEEEEEEEEEECCCCCCEEEEEEEEECCCCCCCCCHHHHCCEEEEEEEC
# Accuracy: 0.0
#
#
# Predicted structure:
#  >CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# True structure:
#  
# Accuracy: 0.33881578947368424
#
#
# Predicted structure:
#  >>C>H>EE>ECEC>>EEEH>>C>>>C>EE>EH>>>H>E>>>>>>>>E>E>C>>>>>>>>>>>>>>>>>C>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>C>>>>>
# True structure:
#  CCECCCCEECCCEEECCCCCEEECCCCCEEECCCEEEECCEEHHHHCCCCCCCEEEECCEEEECCHHHCCCCEECCCECCEEEEECCCCCEECCEEEECCCCCCEEEEHHHEEEC
# Accuracy: 0.06956521739130435
#
#
# Predicted structure:
#  >>H>>HC>>>EECEE>C>E>>>>E>>E>>>>E>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>E>>>>>>>>>>>>>>>E>>>>>>>>>>>>>>>>>>>>>>>>>>>
# True structure:
#  CCEEEEEEEEECCCCEEEEEECCEEEEEECCHHHCCCCCCECHHHHHHHHHHHHHHHHHHHHHHHCCCCEEEEEEEEEEEEEECCCCCEEEEEEEEEEEEEECHHHHHHHHHHHHHHHHHCHHHHHHCCCCEEEEEEEEC
# Accuracy: 0.04285714285714286
#
#
# Predicted structure:
#  >>E>>CEEHEHHCHHHHHHHHCCCHHHHHHHCHHHHHCHCHEHHCHCHHEHHCHHCHEHHHCCECHHCHH>H>HCH>>H>>>>>>>>>>>>H>>>>>>>>>>>>>>>>>>>H>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# True structure:
#  CCEEEEEEEEEEEEECCCHHHHHHHHCCHHHHHCCCCCEEEEEEEECCEEEEEECCECCHHHCECCEEEEEEEEECCCCEEEEEECCCCCCEEEEEEEEEEECCCCCEEEEEEEEEEEEECCCHHHHHHHHHHHHHHHHHHHHHHHHHHHCCCCCCCCCCC
# Accuracy: 0.14285714285714285
#
#
# Predicted structure:
#  >HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHCHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHEHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH>EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# True structure:
#  
# Accuracy: 0.2185929648241206
#
#
# Predicted structure:
#  >HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHCHHHHHHHHHHHHHHHHHHHHHHHEHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH>>>HC>EHHCHCHCCHCHCCCHHHHC>HHHHHH>HHHHHHCHH>C>>>HH>HHEC>H>>>>>>>H>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# True structure:
#  ...
# Accuracy: 0.25295508274231676
#
#
# Average Accuracy: 0.2115320600058027

# %% [markdown]
# #### Q8

# %%
# Preparing Inputs
data = {'x_train':X , 'y_train':Y_q8 , 'x_val':X , 'y_val':Y_q8}
hy = {'batch_size':128 , 'epochs':15 , 'lr':0.005 , 'eval_int':eval_interval ,
      'patience':1 , 'factor':0.35 , 'min_delta':0.05 , 'b1':0.935 , 'b2':0.978}
pr = ProteinTransformer(q8_vocab_size , n_emb=64 , n_head=8 ,
                        ff_multiplier=6 , n_blocks=2 , dropout=0.3)
pr.to(device)
loss_func = nn.CrossEntropyLoss(ignore_index=q8_stoi['.'])
print(f"Model's trainable parameters: {sum([i.numel() for i in pr.parameters()])}")

# Training Loop
tr = Training(data , pr , hy , q8_stoi , loss_func , verbose=True , valid = False)
tr()
# Saving Model
torch.save(pr.state_dict(), 'Q8_protein_transformer_notoken.pth')
# Out:
# Model's trainable parameters: 139043
# Epoch: 1/15 | Training Loss: 0.99849 | Training Accuracy: 0.46068 |Training Precision: 0.37002 | Training F1-Score: 0.39062
# Epoch: 2/15 | Training Loss: 0.89465 | Training Accuracy: 0.48114 |Training Precision: 0.70789 | Training F1-Score: 0.40300
# Epoch: 3/15 | Training Loss: 0.86970 | Training Accuracy: 0.48247 |Training Precision: 0.70397 | Training F1-Score: 0.40508
# Epoch: 4/15 | Training Loss: 0.82010 | Training Accuracy: 0.49298 |Training Precision: 0.71186 | Training F1-Score: 0.41867
# Epoch: 5/15 | Training Loss: 0.69210 | Training Accuracy: 0.51827 |Training Precision: 0.70902 | Training F1-Score: 0.43055
# Epoch: 6/15 | Training Loss: 0.55393 | Training Accuracy: 0.54518 |Training Precision: 0.71748 | Training F1-Score: 0.44816
# Epoch: 7/15 | Training Loss: 0.43884 | Training Accuracy: 0.56709 |Training Precision: 0.73625 | Training F1-Score: 0.46633
# Epoch: 8/15 | Training Loss: 0.37114 | Training Accuracy: 0.58219 |Training Precision: 0.75813 | Training F1-Score: 0.48483
# Epoch: 9/15 | Training Loss: 0.32167 | Training Accuracy: 0.59118 |Training Precision: 0.78549 | Training F1-Score: 0.50566
# Epoch: 10/15 | Training Loss: 0.29577 | Training Accuracy: 0.59580 |Training Precision: 0.81144 | Training F1-Score: 0.52354
# Epoch: 11/15 | Training Loss: 0.28033 | Training Accuracy: 0.59927 |Training Precision: 0.82546 | Training F1-Score: 0.53510
# Epoch: 12/15 | Training Loss: 0.26622 | Training Accuracy: 0.60229 |Training Precision: 0.84071 | Training F1-Score: 0.54653
# Epoch: 13/15 | Training Loss: 0.25157 | Training Accuracy: 0.60429 |Training Precision: 0.84349 | Training F1-Score: 0.54964
# Epoch: 14/15 | Training Loss: 0.24036 | Training Accuracy: 0.60849 |Training Precision: 0.84295 | Training F1-Score: 0.55103
# Epoch: 15/15 | Training Loss: 0.23092 | Training Accuracy: 0.60987 |Training Precision: 0.84686 | Training F1-Score: 0.55534

# %%
# Testing
# Creating initial model
pr = ProteinTransformer(q8_vocab_size , n_emb=64 , n_head=8 ,
                        ff_multiplier=6 , n_blocks=2 , dropout=0.3)
pr.to(device)
# Loading weights
state_dict = torch.load('/content/Q8_protein_transformer_notoken.pth')
pr.load_state_dict(state_dict)
pr.eval()

print(q8_stoi,'\n\n')
count = 0
acc_total = 0
for i in range(df_test.shape[0]):
  count += 1
  # Predicting & Decoding Structure
  pred = q8_decoder(pr.inference(list(df_test['seq'])[i] , seq_encoder).cpu().numpy().flatten()[0:len(list(df_test['sst3'])[i])])
  pred = [item for i in pred for item in (i if isinstance(i, tuple) else [i])][0:len(list(df_test['sst8'])[i])]
  final_pred = ''.join(pred)
  ground_truth = list(df_test['sst8'])[i]
  acc = [1 if i[0] == i[1] else 0 for i in zip(final_pred,ground_truth)]
  acc_perc = sum(acc)/len(acc)
  acc_total += acc_perc

  # Checking Results
  if i % 10 == 0:
    print(f'Predicted structure:\n' , final_pred)
    print(f'True structure:\n' , ground_truth)
    print(f'Accuracy: {acc_perc} \n\n')
print(f'Average Accuracy: {acc_total/count}')

# The model appears to be over-predicting one character for all the sequence, showcasing
# the highly unbalanced nature of the biagrams. Still, the overall accuracy is better than
# chance, but unacceptably low.
# Out:
# <ipython-input-43-58dcf3a1b344>:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('/content/Q8_protein_transformer_notoken.pth')
# {'.': 0, '<': 1, '>': 2, 'B': 3, 'C': 4, 'E': 5, 'G': 6, 'H': 7, 'I': 8, 'S': 9, 'T': 10}
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEETEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE>HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# True structure:
#  
# Accuracy: 0.1529745042492918
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEHEEEEEEEEHEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# True structure:
#  CCCCCGGGCSCGGGCCHHHHHHHHHHHHHHTTCSCCCTTTTCSCHHHHTTCCHHHHHHHCTTTHHHHHHHHHHHHHHHHHHHHCCCCCC
# Accuracy: 0.011235955056179775
#
#
# Predicted structure:
#  >HHEHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# True structure:
#  CCCCCCCHHHHHHHHHHHHHHHHHTTCCEEEEHHHHHHHTCSCTTCCCSSEEEEECCCTTCCCHHHHHHHHHHHCTTTEEEEESSSCEEEEEEEECTTSCEEEEEEEEEETTTCTTCGGGCTTTSCEEEEEETTEEEEEECHHHHHHHHHHHHHHTTTSTTHHHHHHHHHHHGGGCCTTCGGGBCTTCHHHHHHHHHHHHHCGGGHHHHHTTCBCHHHHCC
# Accuracy: 0.3755656108597285
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEHEEEEEEEEEEEEEEEEEEEEEEEEEEE
# True structure:
#  CCCCHHHHHHHHHHHHHHHHHHHHHHHCCSCCCBEEEEEEEEETTEEEEEEEEEEECSSTTCEEEEEEEEECCSCCCCCCHHHHCSEEEEEEEC
# Accuracy: 0.3723404255319149
#
#
# Predicted structure:
#  >HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH>EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# True structure:
#  
# Accuracy: 0.34868421052631576
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEHEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEHEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# True structure:
#  CCBCTTSBBSSCEEETTTCCEEECTTSSEEECCCEEEECSEEGGGGSTTSCCCEEEECCEEEESCGGGCSSCEECCCBTTEEEEECTTTCEECSEEEETTCTTCEEEEGGGEEEC
# Accuracy: 0.3565217391304348
#
#
# Predicted structure:
#  >TTTTTTHTTTTTTTTTHTTTTTTTTHTTTTTHTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# True structure:
#  CCEEEEEEEEECSTTEEEEEETTEEEEEECCGGGTCCSSSBCHHHHHHHHHHHHHHHHHHHHHHHTTCCEEEEEEEEEEEEEECTTSSEEEEEEEEEEEEEECGGGGGGHHHHHHHHHHHCHHHHHHTTTSEEEEEEEEC
# Accuracy: 0.08571428571428572
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEHEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEETEEEEEEEEEEEEEEEEEEEEE
# True structure:
#  CCEEEEEEEEEEEEESSCHHHHHHHHTCHHHHHTTSTTEEEEEEEETTEEEEEECCBSSGGGCBCCEEEEEEEEETTTTEEEEEECTTSTTEEEEEEEEEEESSSSCEEEEEEEEEEEEECSCGGGHHHHHHHHHHHHHHHHHHHHHHHHTTTSSSSCCCC
# Accuracy: 0.40372670807453415
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEHEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE>HHHHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# True structure:
#  
# Accuracy: 0.27889447236180903
#
#
# Predicted structure:
#  >EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE>HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# True structure:
#  ...
# Accuracy: 0.2553191489361702
#
#
# Average Accuracy: 0.26971225488850076
